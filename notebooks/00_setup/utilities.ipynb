# %% [markdown]
# # Utility Configuration
#
# This notebook defines shared configuration values used across the FMCG Lakehouse pipeline.
# Centralizing these values ensures consistency across Bronze, Silver, and Gold processing notebooks
# and avoids hardcoding schema names in multiple locations.

# %% [markdown]
# ## Medallion Schema Configuration
#
# These schema names are reused across setup, dimension, and fact processing notebooks.

# %%
bronze_schema = "bronze"
silver_schema = "silver"
gold_schema = "gold"
